# %%
from glob import glob
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
all_img_paths = glob('./training/*.png')
len(img_paths)
# Out:
# 275

# %% [markdown]
# ## Real Image

# %%
Image.open([img for img in all_img_paths if 'real' in img][0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FB564CFDD60>

# %% [markdown]
# ## Undersampled Image

# %%
Image.open([img for img in all_img_paths if 'undersampled' in img][0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7FB566BA5D60>

# %% [markdown]
# ## Learning Progress

# %%
fake_img_paths = [path for path in all_img_paths if 'fake' in path]
len(fake_img_paths)
# Out:
# 273

# %%
fake_img_paths = sorted(fake_img_paths, key=lambda x: int(x[(x.index('fake') + 5):x.rindex('.')]))
fake_imgs = [np.array(Image.open(path)) for path in fake_img_paths]

# %%
import imageio

imageio.mimsave('./training/learning.gif', fake_imgs)
